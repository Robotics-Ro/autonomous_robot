# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'NanumGothic'

# %%
pwd
# Out:
# '/home/thro/Documents/amr_ws/02_ws/EDA_project/src'

# %%
df_26=pd.read_csv("../data/사용할 데이터/26pg_로봇산업 대분류별 추정된 로봇산업 사업체.csv")

# %%
df_26
# Out:
#   대분류 코드          대분류명  로봇산업 사업체 수  구성비(%)
# 0    100       제조업용 로봇         525    12.2
# 1    200     전문서비스용 로봇         244     5.7
# 2    300     개인서비스용 로봇         106     2.5
# 3    400  로봇부품 및 소프트웨어        1360    31.6
# 4    500         로봇시스템         742    17.2
# 5    600        로봇임베디드         158     3.7
# 6    900         로봇서비스        1175    27.3
# 7    총합            총합         4310   100.0

# %%
# df_26=pd.pivot_table(df_26,index=["대분류 코드","대분류명","로봇산업 사업체 수","구성비(%)"])
# df_26



# new_df

df_26.rename(columns={'대분류 코드':'code',"대분류명":'name',"로봇산업 사업체 수":'count',"구성비(%)":'percentage'}, inplace=True)


df_26 = df_26.drop(index=7, axis = 0)
# plt.pie(new_df, new_df, autopct='%.1f%%', startangle=260, counterclock=False)
# plt.show()

# %%
df_26['percentage']
# Out:
# 0    12.2
# 1     5.7
# 2     2.5
# 3    31.6
# 4    17.2
# 5     3.7
# 6    27.3
# Name: percentage, dtype: float64

# %%
plt.axis('equal')
plt.pie(df_26['percentage'], labels=df_26['name'], autopct='%.1f%%', startangle=260, counterclock=False, explode=[0.01,0.01,0.01,0.01,0.01,0.01,0.01])
plt.savefig('circle0.png', transparent = True)
plt.show()

# %%
df_27=pd.read_csv("../data/사용할 데이터/27pg_대분류별 비례배분법과 변형비례배분법의 할당결과.csv")
df_27=pd.pivot_table(df_27,index=["대분류 코드","대분류명",	"모집단",	"비례배분 할당표본",	"비례배분 기대표본오차",	"20+비례배분 할당표본",	"20+비례배분 기대표본오차"]
)
df_27
# Out:
# Empty DataFrame
# Columns: []
# Index: [(100.0, 제조업용 로봇, 525, 121, 7.93, 125, 7.81), (200.0, 전문서비스용 로봇, 244, 57, 11.6, 69, 10.2), (300.0, 개인서비스용 로봇, 106, 25, 17.48, 41, 12.23), (400.0, 로봇부품 및 소프트웨어, 1360, 316, 4.93, 291, 5.2), (500.0, 로봇시스템, 742, 172, 6.68, 168, 6.79), (600.0, 로봇임베디드, 158, 37, 14.39, 52, 11.36), (900.0, 로봇서비스, 1175, 272, 5.3, 254, 5.56)]

# %%
df_28=pd.read_csv("../data/사용할 데이터/28pg_조사사업체수.csv")
df_28
new_df = df_28.drop(2, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_28=pd.read_csv("../data/사용할 데이터/28pg_조사사업체수.csv")
#       2 df_28
#       3 new_df = df_28.drop(2, axis = 1)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/사용할 데이터/28pg_조사사업체수.csv'

# %%
df_40=pd.read_csv("../../../../../Downloads/2019년 기준 로봇산업 실태조사/2019년 기준 로봇산업 실태조사_csv/40pg_로봇및 소프트웨어.csv")
df_40
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_40=pd.read_csv("../../../../../Downloads/2019년 기준 로봇산업 실태조사/2019년 기준 로봇산업 실태조사_csv/40pg_로봇및 소프트웨어.csv")
#       2 df_40
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../../../Downloads/2019년 기준 로봇산업 실태조사/2019년 기준 로봇산업 실태조사_csv/40pg_로봇및 소프트웨어.csv'

# %%
df_41=pd.read_csv("../../../../../Downloads/2019년 기준 로봇산업 실태조사/2019년 기준 로봇산업 실태조사_csv/41pg_인력(취업)현황.csv")
df_41
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_41=pd.read_csv("../../../../../Downloads/2019년 기준 로봇산업 실태조사/2019년 기준 로봇산업 실태조사_csv/41pg_인력(취업)현황.csv")
#       2 df_41
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/venv/data_venv/lib/python3.8/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../../../Downloads/2019년 기준 로봇산업 실태조사/2019년 기준 로봇산업 실태조사_csv/41pg_인력(취업)현황.csv'

# %%
df_44=pd.read_csv("../data/사용할 데이터/44pg_사업체 현황_최근 3개년도 사업체 근황.csv")
df_44 = df_44.drop(index=4, axis = 0)
df_44
# Out:
#           robot  2017  Per_2017  2018  Per_2018  2019  Per_2019 18년 대비 증감
# 0         제조업용    718      32.8   827      33.0   525      23.5      36.5
# 1       전문 서비스용   300      13.7   368      14.7   244      10.9     △33.7
# 2       개인 서비스용   172       7.9   208       8.3   106       4.7        49
# 3  로봇부품 및 소프트웨어  1001      45.7  1105      44.1  1360      60.9      23.1

# %%
#new_df = df_45.drop(df_45.columns[4], axis = 1, inplace=True)
year_44 = df_44.copy()
year_44.drop([df_44.columns[2],df_44.columns[4],df_44.columns[6],df_44.columns[7]], axis=1, inplace=True)

# %%
per_44 = df_44.copy()
per_44.drop([df_44.columns[1],df_44.columns[3],df_44.columns[5],df_44.columns[7]], axis=1, inplace=True)

# %%
per_44
# Out:
#           robot  Per_2017  Per_2018  Per_2019
# 0         제조업용       32.8      33.0      23.5
# 1       전문 서비스용      13.7      14.7      10.9
# 2       개인 서비스용       7.9       8.3       4.7
# 3  로봇부품 및 소프트웨어      45.7      44.1      60.9

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
year_44.plot(stacked=True, ax=ax[0])
per_44.plot(stacked=True, ax=ax[1])
# Out:
# <AxesSubplot: >

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
ax[0].bar(df_44['robot'], df_44['2017'])
ax[1] = plt.pie(df_44['Per_2017'], labels=df_44['robot'], autopct='%.1f%%', startangle=260, counterclock=False)
plt.savefig('2017.png', transparent = True)
#ax[0].set_title('Pie plot - Survived')
# ax[0].set_ylabel('')
# sns.countplot(x='survived', data=titanic, ax=ax[1])
# ax[1].set_title('Count plot - Survived')

plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
ax[0].bar(df_44['robot'], df_44['2018'])
ax[1] = plt.pie(df_44['Per_2018'], labels=df_44['robot'], autopct='%.1f%%', startangle=260, counterclock=False)
plt.savefig('2018.png', transparent = True)
#ax[0].set_title('Pie plot - Survived')
# ax[0].set_ylabel('')
# sns.countplot(x='survived', data=titanic, ax=ax[1])
# ax[1].set_title('Count plot - Survived')

plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
ax[0].bar(df_44['robot'], df_44['2019'])
ax[1] = plt.pie(df_44['Per_2019'], labels=df_44['robot'], autopct='%.1f%%', startangle=260, counterclock=False)
plt.savefig('2019.png', transparent = True)
#ax[0].set_title('Pie plot - Survived')
# ax[0].set_ylabel('')
# sns.countplot(x='survived', data=titanic, ax=ax[1])
# ax[1].set_title('Count plot - Survived')

plt.show()

# %%
df_45=pd.read_csv("../data/사용할 데이터/45pg_부분별 사업체 규모.csv")
df_45
# Out:
#              로봇   대기업  중견기업  중소기업     합
# 0          제조업용    10    18   497   525
# 1       전문 서비스용     0    10   234   244
# 2        개인 서비스용    9     0    97   106
# 3  로봇부품 및 소프트웨어     1     8  1351  1360
# 4              총   20    36  2179  2235

# %%
df_45.rename(columns={'로봇 ':'robot',"대기업":'big',"중견기업":'middle',"중소기업":'small','합':'Total'}, inplace=True)
df_45
# Out:
#            robot  big  middle  small  Total
# 0          제조업용    10      18    497    525
# 1       전문 서비스용     0      10    234    244
# 2        개인 서비스용    9       0     97    106
# 3  로봇부품 및 소프트웨어     1       8   1351   1360
# 4              총   20      36   2179   2235

# %%
new_df = df_45.drop(4, axis = 0)

# %%
#new_df = df_45.drop(df_45.columns[4], axis = 1, inplace=True)
new_df = df_45.drop(4, axis = 0)
new_df
# Out:
#            robot  big  middle  small  Total
# 0          제조업용    10      18    497    525
# 1       전문 서비스용     0      10    234    244
# 2        개인 서비스용    9       0     97    106
# 3  로봇부품 및 소프트웨어     1       8   1351   1360

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
new_df.plot.bar(stacked=True, ax=ax[0])
ax[1] = plt.pie(new_df['Total'], labels=new_df['robot'], autopct='%.1f%%', startangle=260, counterclock=False)
plt.title('사업체의 총 비율')
plt.savefig('Total.png', transparent = True)
plt.show()

# %%
tmp_df = df_45.drop(df_45.columns[4], axis = 1, inplace=True)
tmp_df = df_45.drop(4, axis = 0)
tmp_df
# Out:
#            robot  big  middle  small
# 0          제조업용    10      18    497
# 1       전문 서비스용     0      10    234
# 2        개인 서비스용    9       0     97
# 3  로봇부품 및 소프트웨어     1       8   1351

# %%
#tmp_df.pivot('robot', tmp_df.columns, )

# %%
#plt.bar(tmp_df['robot'], tmp_df.columns)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_48=pd.read_csv("../data/사용할 데이터/48pg_연도별 사업체 설립 변화.csv")
df_48
# Out:
#             구 분    전체    구성비  제조업용 로봇  구성비.1  전문 서비스용 로봇  구성비.2  개인 서비스용 로봇  \
# 0      1990년 이전   135    6.1       51    9.7          26   10.7           1
# 1   1990년~1994년   110    4.9       18    3.4           1    0.4           8
# 2  1995년~1999년    324   14.5      118   22.5          28   11.3           7
# 3   2000년~2004년   421   18.9      110   21.0          28   11.5          14
# 4      2005년 이후  1239   55.6      228   43.4         161   66.1          76
# 5          총 계   2229  100.0      525  100.0         244  100.0         106
#
#    구성비.3  로봇부품 및 소프트웨어  구성비.4
# 0    0.9            57    4.2
# 1    7.2            84    6.1
# 2    6.2           172   12.7
# 3   13.5           268   19.7
# 4   72.1           774   56.9
# 5  100.0          1355  100.0

# %%
df_48.rename(columns={'전체':'Total',"구성비":'Per0',"제조업용 로봇":'manufacture',"구성비.1":'Per1','전문 서비스용 로봇':'Service', '구성비.2':'Per2', '개인 서비스용 로봇' : 'Personal', '구성비.3':'Per3', '로봇부품 및 소프트웨어':'software','구성비.4':'Per4'}, inplace=True)
df_48
# Out:
#             구 분  Total   Per0  manufacture   Per1  Service   Per2  Personal  \
# 0      1990년 이전    135    6.1           51    9.7       26   10.7         1
# 1   1990년~1994년    110    4.9           18    3.4        1    0.4         8
# 2  1995년~1999년     324   14.5          118   22.5       28   11.3         7
# 3   2000년~2004년    421   18.9          110   21.0       28   11.5        14
# 4      2005년 이후   1239   55.6          228   43.4      161   66.1        76
# 5          총 계    2229  100.0          525  100.0      244  100.0       106
#
#     Per3  software   Per4
# 0    0.9        57    4.2
# 1    7.2        84    6.1
# 2    6.2       172   12.7
# 3   13.5       268   19.7
# 4   72.1       774   56.9
# 5  100.0      1355  100.0

# %%
df_48.rename(columns={'구 분':'Category'}, inplace=True)

# %%
df_48.drop(5, axis = 0, inplace = True)

# %%
df_48
# Out:
#        Category  Total   Per0  manufacture   Per1  Service   Per2  Personal  \
# 0      1990년 이전    135    6.1           51    9.7       26   10.7         1
# 1   1990년~1994년    110    4.9           18    3.4        1    0.4         8
# 2  1995년~1999년     324   14.5          118   22.5       28   11.3         7
# 3   2000년~2004년    421   18.9          110   21.0       28   11.5        14
# 4      2005년 이후   1239   55.6          228   43.4      161   66.1        76
# 5          총 계    2229  100.0          525  100.0      244  100.0       106
#
#     Per3  software   Per4
# 0    0.9        57    4.2
# 1    7.2        84    6.1
# 2    6.2       172   12.7
# 3   13.5       268   19.7
# 4   72.1       774   56.9
# 5  100.0      1355  100.0

# %%
#꺾은선 그래프
#plc.xtics
plt.plot(df_48['Category'], df_48['Total'])
plt.plot(df_48['Category'], df_48['manufacture'])
plt.plot(df_48['Category'], df_48['Service'])
plt.plot(df_48['Category'], df_48['Personal'])
plt.plot(df_48['Category'], df_48['software'])
plt.legend(['전체','제조업용 로봇', '전문 서비스용 로봇','개인 서비스용 로봇', '로봇 부품 및 소프트웨어'])
plt.xticks
plt.savefig('year.png', transparent = True)
plt.show()

# %%
df_140=pd.read_csv("../data/사용할 데이터/140pg_최근 3개년도 인력 현황.csv")

# %%
df_140.rename(columns={'구 분':'Category','2017년 ':'2017',"구성비":'Per0',"2018년 ":'2018',"구성비.1":'Per1','2019년':'2019', '구성비.2':'Per2', ' ''18년 대비 증감률' : '18_increment'}, inplace=True)
df_140
# Out:
#         Category   2017   Per0   2018   Per1   2019   Per2 ‘18년 대비  증감률
# 0       제조업용 로봇   11511   28.5  15990   32.7  11754   23.2        △26.5
# 1     전문서비스용 로봇    3002    7.4   3706    7.6   3330    6.6        △10.1
# 2     개인서비스용 로봇    2196    5.4   2438    5.0   1795    3.5        △26.4
# 3  로봇부품 및 소프트웨어   12388   30.7  14970   30.6  14156   27.9         △5.4
# 4          로봇시스템   6007   14.9   6386   13.0   8857   17.5         38.7
# 5         로봇임베디드   1299    3.2   1199    2.5   1933    3.8         61.2
# 6          로봇서비스   3932    9.7   4251    8.7   8922   17.6        109.8
# 7           총 계   40334  100.0  48939  100.0  50746  100.0          3.7

# %%
df_140.drop([df_140.columns[2],df_140.columns[4],df_140.columns[6],df_140.columns[7]], axis=1)
# Out:
#         Category   2017   2018   2019
# 0       제조업용 로봇   11511  15990  11754
# 1     전문서비스용 로봇    3002   3706   3330
# 2     개인서비스용 로봇    2196   2438   1795
# 3  로봇부품 및 소프트웨어   12388  14970  14156
# 4          로봇시스템   6007   6386   8857
# 5         로봇임베디드   1299   1199   1933
# 6          로봇서비스   3932   4251   8922
# 7           총 계   40334  48939  50746

# %%
df_140.set_index("Category", inplace=True)

# %%
df_140.drop([df_140.columns[1],df_140.columns[3],df_140.columns[5],df_140.columns[6]], axis=1, inplace=True)

# %%
df_140.drop(['총 계 '], axis = 0, inplace=True)

# %%
df_140
# Out:
#                 2017   2018   2019
# Category
# 제조업용 로봇        11511  15990  11754
# 전문서비스용 로봇       3002   3706   3330
# 개인서비스용 로봇       2196   2438   1795
# 로봇부품 및 소프트웨어   12388  14970  14156
# 로봇시스템           6007   6386   8857
# 로봇임베디드          1299   1199   1933
# 로봇서비스           3932   4251   8922

# %%
for i,row in df_140.iterrows():
    plt.plot(row)
plt.legend(['제조업용 로봇', '전문서비스용 로봇', '개인 서비스용 로봇', '로봇부품 및 소프트웨어', '로봇시스템', '로봇임베디드', '로봇서비스'], loc=(0.05,0.4))

plt.savefig('human_resource.png', transparent = True)

# %%
plt.plot(df_140['Category'], ['Total'])
plt.plot(df_48['Category'], df_48['manufacture'])
plt.plot(df_48['Category'], df_48['Service'])
plt.plot(df_48['Category'], df_48['Personal'])
plt.plot(df_48['Category'], df_48['software'])
plt.legend(['전체','제조업용 로봇', '전문 서비스용 로봇','개인 서비스용 로봇', '로봇 부품 및 소프트웨어'])

# %%
plt.plot(df_140['Category'], df_140['2016'][0])
# plt.plot(df_140['Category'], df_140['manufacture'])
# plt.plot(df_140['Category'], df_140['Service'])
# plt.plot(df_140['Category'], df_140['Personal'])
# plt.plot(df_140['Category'], df_140['software'])
# plt.legend(['전체','제조업용 로봇', '전문 서비스용 로봇','개인 서비스용 로봇', '로봇 부품 및 소프트웨어', '로봇 시스템', ''])
# plt.xticks

# %%
df = pd.read_excel('../data/saramin_df_real_total_O1.xlsx')
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0              회사명  \
# 0             0           0       (주)로봇앤드디자인
# 1             1           1             ㈜덴티움
# 2             2           2  (주)글로벌스탠다드테크놀로지
# 3             3           3       (주)로봇앤드디자인
# 4             4           4       (주)포스코아이씨티
#
#                                  직무  \
# 0    '23년 상반기 로봇 및 자동화 장비 제어 정규직 채용
# 1              [덴티움] 센서/로봇 SW개발자 모집
# 2                   로봇 기획&마케팅 경력 채용
# 3  [첨단로봇연구소] 로봇 및 자동화 설계/제어 경력사원 채용
# 4              로봇사업 분야 신입/경력 정규직 채용
#
#                                                  URL         근무지     경력    학위  \
# 0  https://www.saramin.co.kr/zf_user/jobs/relay/v...        경기전체  신입·경력  초대졸↑
# 1  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경기 수원시 영통구  신입·경력   대졸↑
# 2  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경기 성남시 분당구  경력5년↑   대졸↑
# 3  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경기 용인시 처인구     경력  학력무관
# 4  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경기 성남시 분당구  신입·경력   대졸↑
#
#     유형                                               사내복지  \
# 0  NaN                                                NaN
# 1  NaN  지원금/보험\n건강검진, 각종 경조사 지원, 업무활동비 지급, 선택적복리후생\n급여...
# 2  NaN                                                NaN
# 3  NaN  지원금/보험\n건강검진, 각종 경조사 지원\n급여제도\n퇴직금, 야근수당, 휴일(특...
# 4  NaN                                                NaN
#
#                                                상세 주소  \
# 0                                                NaN
# 1  (16229) 경기 수원시 영통구 창룡대로256번길 76 덴티움 지식산업센터(이의동...
# 2                                                NaN
# 3                                                NaN
# 4            (13486) 경기 성남시 분당구 판교로 255 판교 이노밸리(삼평동)
#
#                                                기업 정보  \
# 0  기업형태\n중소기업, 스타트업, 수출입 기업\n사원수\n134 명 (2021년 기준...
# 1  기업형태\n코스피, 중견기업, 외부감사법인, 연구소..\n사원수*\n670 명 (2...
# 2  기업형태\n코스닥, 중견기업, 주식회사, 외부감사법..\n사원수\n665 명 (20...
# 3  기업형태\n중소기업, 스타트업, 수출입 기업\n사원수\n134 명 (2021년 기준...
# 4  기업형태\n코스닥, 대기업, 1000대기업\n사원수\n2016 명 (2022년 기준...
#
#                                               지원자 통계  \
# 0  지원자수\n16명\n로봇 및 자동화장비 제어\n16명\n경력별 현황\n신입\n7\n...
# 1  지원자수\n2명\n센서 시스템/다관절 로봇제어 SW개발\n2명\n경력별 현황\n신입...
# 2  지원자수\n8명\n비즈니스/제품/서비스 기획 & 마케팅\n8명\n경력별 현황\n신입...
# 3  지원자수\n5명\n첨단 로봇 및 시스템 개발 (설계 및 제어)\n5명\n경력별 현황...
# 4  지원자수\n9명\n반도체 공정개발\n9명\n경력별 현황\n신입\n0\n1년 미만\n...
#
#                                                 세부정보  \
# 0  모집부분\n모집부문 지원자격 및 우대사항 인원\n로봇 및\n자동화장비\n제어 지원자...
# 1  [덴티움]\n센서/로봇 SW개발자 모집\n\n모집부문 및 상세내용\n\n모집부문 상...
# 2  모집부문 및 자격요건\n모집부문 경력 사항 담당업무 자격요건 및 우대사항\n비즈니스...
# 3                                                NaN
# 4  로봇사업 분야 신입/경력 정규직 채용\n모집부문 및 상세내용\n모집부문 상세내용\n...
#
#                   Unnamed: 14  \
# 0  공정자동화 및 로봇 통합 구동(모션)제어기 제조
# 1          로봇용 가속도 및 속도 센서 제조
# 2                          기타
# 3               기타 제조업용 로봇 제조
# 4                         NaN
#
#                                          Unnamed: 15
# 0  공정자동화 및 로봇(단축 이송로봇 포함) 통합 구동제어기 제조(별도 축 제어모듈 장...
# 1  로봇  구동 및 동작에 필요한 가속도 및 속도 인식정보를 감지ㆍ처리하는 센서 및 관...
# 2                                                 기타
# 3                                                NaN
# 4                                                NaN
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
