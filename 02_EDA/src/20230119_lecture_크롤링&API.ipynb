# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothicCoding')

# %%
plt.figure(figsize=(5,5))
plt.plot([0,1], [0,1], label='한글테스트용')
plt.legend()
plt.show()

# %%
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen

url = "https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20180315"
page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&amp;date=20180315" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all("div","tit5")
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=151196" title="원더">원더</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=106360" title="위대한 쇼맨">위대한 쇼맨</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=18847" title="타이타닉">타이타닉</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=151752" title="온리 더 브레이브">온리 더 브레이브</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=31013" title="빌리 엘리어트">빌리 엘리어트</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=172006" title="젝스키스 에이틴">젝스키스 에이틴</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=151728" title="코코">코코</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=144379" title="러빙 빈센트">러빙 빈센트</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=152160" title="킹 오브 프리즘 한국어판">킹 오브 프리즘 한국어판</a>
#  </div>,
# ...

# %%
soup.find_all("div", "tit5")[0].a
# Out:
# <a href="/movie/bi/mi/basic.naver?code=151196" title="원더">원더</a>

# %%
soup.find_all("div", "tit5")[0].a.string
# Out:
# '원더'

# %%
movie_name = [each.a.string for each in soup.find_all('div', 'tit5')]
movie_point= [each.get_text() for each in soup.find_all("td", "point")]
movie_point
# Out:
# ['9.40',
#  '9.38',
#  '9.29',
#  '9.28',
#  '9.28',
#  '9.25',
#  '9.22',
#  '9.19',
#  '9.19',
#  '9.17',
#  '9.12',
#  '9.10',
#  '9.01',
#  '8.96',
#  '8.89',
#  '8.85',
#  '8.81',
#  '8.80',
#  '8.78',
#  '8.78',
#  '8.69',
#  '8.59',
#  '8.49',
#  '8.49',
#  '8.44',
#  '8.33',
#  '8.31',
#  '8.31',
#  '8.30',
#  '8.27',
#  '8.12',
#  '8.07',
#  '8.06',
#  '8.05',
#  '7.95',
#  '7.91',
#  '7.55',
#  '7.53',
#  '7.47',
#  '7.28',
#  '7.04',
#  '6.79',
#  '6.33',
#  '5.46',
#  '4.74',
#  '1.46']

# %%
soup.find_all("td", "point")
# Out:
# [<td class="point">9.40</td>,
#  <td class="point">9.38</td>,
#  <td class="point">9.29</td>,
#  <td class="point">9.28</td>,
#  <td class="point">9.28</td>,
#  <td class="point">9.25</td>,
#  <td class="point">9.22</td>,
#  <td class="point">9.19</td>,
#  <td class="point">9.19</td>,
#  <td class="point">9.17</td>,
#  <td class="point">9.12</td>,
#  <td class="point">9.10</td>,
#  <td class="point">9.01</td>,
#  <td class="point">8.96</td>,
#  <td class="point">8.89</td>,
#  <td class="point">8.85</td>,
#  <td class="point">8.81</td>,
#  <td class="point">8.80</td>,
#  <td class="point">8.78</td>,
#  <td class="point">8.78</td>,
#  <td class="point">8.69</td>,
#  <td class="point">8.59</td>,
#  <td class="point">8.49</td>,
#  <td class="point">8.49</td>,
#  <td class="point">8.44</td>,
#  <td class="point">8.33</td>,
#  <td class="point">8.31</td>,
#  <td class="point">8.31</td>,
#  <td class="point">8.30</td>,
#  <td class="point">8.27</td>,
#  <td class="point">8.12</td>,
# ...

# %%
len(soup.find_all("td", "point"))
# Out:
# 46

# %%
soup.find_all("td", "point")[0].string
# Out:
# '9.40'

# %%
len(movie_name), len(movie_point)
# Out:
# (46, 46)

# %%
date = pd.date_range('2019.10.01', periods=31, freq='D')
date
# Out:
# DatetimeIndex(['2019-10-01', '2019-10-02', '2019-10-03', '2019-10-04',
#                '2019-10-05', '2019-10-06', '2019-10-07', '2019-10-08',
#                '2019-10-09', '2019-10-10', '2019-10-11', '2019-10-12',
#                '2019-10-13', '2019-10-14', '2019-10-15', '2019-10-16',
#                '2019-10-17', '2019-10-18', '2019-10-19', '2019-10-20',
#                '2019-10-21', '2019-10-22', '2019-10-23', '2019-10-24',
#                '2019-10-25', '2019-10-26', '2019-10-27', '2019-10-28',
#                '2019-10-29', '2019-10-30', '2019-10-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
date[0]
# Out:
# Timestamp('2019-10-01 00:00:00', freq='D')

# %%
date[0].strftime('%y-%m-%d')
# Out:
# '19-10-01'

# %%
date[0].strftime('%y. %m. %d')
# Out:
# '19. 10. 01'

# %%
type(date[0].strftime('%y. %m. %d'))
# Out:
# str

# %%
date[0].strftime('%y%m%d')
# Out:
# '191001'

# %%
date[0].strftime('%Y%m%d')
# Out:
# '20191001'

# %%
import time

movie_date = []
movie_name = []
movie_point = []

# %%
for today in date:
    html = "http://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"
    response = urlopen(html.format(date = today.strftime('%Y%m%d')))
    soup = BeautifulSoup(response, "html.parser")
    
    movie_date.extend([today]*len(soup.find_all('td', 'point')))
    movie_name.extend([each.a.string for each in soup.find_all('div', 'tit5')])
    movie_point.extend([each.string for each in soup.find_all('td', 'point')])
    
    print(str(today))
    time.sleep(1)
# Out:
# 2019-10-01 00:00:00
# 2019-10-02 00:00:00
# 2019-10-03 00:00:00
# 2019-10-04 00:00:00
# 2019-10-05 00:00:00
# 2019-10-06 00:00:00
# 2019-10-07 00:00:00
# 2019-10-08 00:00:00
# 2019-10-09 00:00:00
# 2019-10-10 00:00:00
# 2019-10-11 00:00:00
# 2019-10-12 00:00:00
# 2019-10-13 00:00:00
# 2019-10-14 00:00:00
# 2019-10-15 00:00:00
# 2019-10-16 00:00:00
# 2019-10-17 00:00:00
# 2019-10-18 00:00:00
# 2019-10-19 00:00:00
# 2019-10-20 00:00:00
# 2019-10-21 00:00:00
# 2019-10-22 00:00:00
# 2019-10-23 00:00:00
# 2019-10-24 00:00:00
# 2019-10-25 00:00:00
# 2019-10-26 00:00:00
# 2019-10-27 00:00:00
# 2019-10-28 00:00:00
# 2019-10-29 00:00:00
# 2019-10-30 00:00:00
# 2019-10-31 00:00:00

# %%
len(movie_date), len(movie_name), len(movie_point)
# Out:
# (1255, 1255, 1255)

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':movie_point})
movie.head()
# Out:
#         date        name point
# 0 2019-10-01      사랑의 선물  9.64
# 1 2019-10-01         주전장  9.54
# 2 2019-10-01      안녕 베일리  9.46
# 3 2019-10-01         알라딘  9.39
# 4 2019-10-01  폴란드로 간 아이들  9.33

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1255 entries, 0 to 1254
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1255 non-null   datetime64[ns]
#  1   name    1255 non-null   object
#  2   point   1255 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 29.5+ KB

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1255 entries, 0 to 1254
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1255 non-null   datetime64[ns]
#  1   name    1255 non-null   object
#  2   point   1255 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 29.5+ KB

# %%
movie.to_csv("../data/naver_movie.csv", sep=",", encoding="utf-8")

# %%
import numpy as np
import pandas as pd

movie = pd.read_csv("../data/naver_movie.csv", index_col=0)
movie.head()
# Out:
#          date        name  point
# 0  2019-10-01      사랑의 선물   9.64
# 1  2019-10-01         주전장   9.54
# 2  2019-10-01      안녕 베일리   9.46
# 3  2019-10-01         알라딘   9.39
# 4  2019-10-01  폴란드로 간 아이들   9.33

# %%
movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_unique.head()
# Out:
# /tmp/ipykernel_3704/2577569102.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
#                point
# name
# 47미터 2        224.98
# 82년생 김지영       54.59
# 가장 보통의 연애     241.22
# 교회오빠          287.59
# 그것: 두 번째 이야기  112.10

# %%
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best.head(10)
# Out:
#                 point
# name
# 주전장            294.99
# 교회오빠           287.59
# 폴란드로 간 아이들     279.65
# 벌새             276.92
# 조커             263.69
# 우리집            263.50
# 기생충            262.88
# 장사리 : 잊혀진 영웅들  260.13
# 엑시트            257.37
# 가장 보통의 연애      241.22

# %%
movie.query('name == ["조커"]')
# Out:
#             date name  point
# 41    2019-10-02   조커   9.27
# 77    2019-10-03   조커   9.12
# 113   2019-10-04   조커   9.05
# 150   2019-10-05   조커   8.98
# 190   2019-10-06   조커   8.91
# 224   2019-10-07   조커   8.87
# 257   2019-10-08   조커   8.86
# 290   2019-10-09   조커   8.83
# 321   2019-10-10   조커   8.82
# 355   2019-10-11   조커   8.80
# 395   2019-10-12   조커   8.78
# 436   2019-10-13   조커   8.75
# 476   2019-10-14   조커   8.75
# 515   2019-10-15   조커   8.74
# 552   2019-10-16   조커   8.74
# 587   2019-10-17   조커   8.74
# 626   2019-10-18   조커   8.73
# 666   2019-10-19   조커   8.72
# 706   2019-10-20   조커   8.71
# 749   2019-10-21   조커   8.71
# 795   2019-10-22   조커   8.71
# 840   2019-10-23   조커   8.71
# 888   2019-10-24   조커   8.71
# 936   2019-10-25   조커   8.70
# 984   2019-10-26   조커   8.67
# 1030  2019-10-27   조커   8.66
# 1077  2019-10-28   조커   8.66
# 1124  2019-10-29   조커   8.66
# 1176  2019-10-30   조커   8.66
# 1224  2019-10-31   조커   8.67

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(movie.query('name == ["조커"]')['date'],
        movie.query('name == ["조커"]')['point'])
plt.xticks('')
plt.ylim((5,10))
plt.grid()
plt.show()

# %%
movie_best.head(10)
# Out:
#                 point
# name
# 주전장            294.99
# 교회오빠           287.59
# 폴란드로 간 아이들     279.65
# 벌새             276.92
# 조커             263.69
# 우리집            263.50
# 기생충            262.88
# 장사리 : 잊혀진 영웅들  260.13
# 엑시트            257.37
# 가장 보통의 연애      241.22

# %%
movie_best.tail(10)
# Out:
#                       point
# name
# 터미네이터: 다크 페이트         17.85
# 델마와 루이스               17.84
# 날씨의 아이                15.96
# 내 사랑                   9.17
# 메밀꽃, 운수 좋은 날, 그리고 봄봄   8.75
# 소중한 날의 꿈               8.58
# 내안의 그놈                 8.24
# 봉오동 전투                 7.89
# 분노의 질주: 홉스&쇼           7.86
# 퍼스트맨                   6.96

# %%
movie_pivot = pd.pivot_table(movie, index=['date'], columns=['name'])
movie_pivot.columns = movie_pivot.columns.droplevel([0])
movie_pivot.head()
# Out:
# name        47미터 2  82년생 김지영  가장 보통의 연애  교회오빠  그것: 두 번째 이야기    그녀  그린 북  \
# date
# 2019-10-01    7.29       NaN        NaN  9.28          6.23  8.50   NaN
# 2019-10-02    7.29       NaN       8.25  9.28          6.24  8.50   NaN
# 2019-10-03    7.29       NaN       8.36  9.28          6.23  8.51   NaN
# 2019-10-04    7.29       NaN       8.36  9.28          6.23  8.51   NaN
# 2019-10-05    7.29       NaN       8.33  9.28          6.24  8.51   NaN
#
# name        극장판 헬로카봇 : 달나라를 구해줘!  기담   기생충  ...  터미네이터 2:오리지널  터미네이터: 다크 페이트  \
# date                                        ...
# 2019-10-01                  7.52 NaN  8.48  ...           NaN            NaN
# 2019-10-02                  7.51 NaN  8.48  ...           NaN            NaN
# 2019-10-03                  7.51 NaN  8.48  ...           NaN            NaN
# 2019-10-04                  7.50 NaN  8.48  ...           NaN            NaN
# 2019-10-05                  7.51 NaN  8.48  ...           NaN            NaN
#
# ...

# %%
movie_pivot.columns
# Out:
# Index(['47미터 2', '82년생 김지영', '가장 보통의 연애', '교회오빠', '그것: 두 번째 이야기', '그녀', '그린 북',
#        '극장판 헬로카봇 : 달나라를 구해줘!', '기담', '기생충', '김광석', '김군', '김복동',
#        '나는 내일, 어제의 너와 만난다', '나랏말싸미', '나쁜 녀석들: 더 무비', '날씨의 아이', '내 사랑',
#        '내안의 그놈', '너의 이름은.', '다이빙벨', '더 룸', '델마와 루이스', '두번할까요', '람보 : 라스트 워',
#        '레드슈즈', '레플리카', '로마의 휴일', '마담 프루스트의 비밀정원', '말레피센트 2', '매디슨 카운티의 다리',
#        '메기', '메밀꽃, 운수 좋은 날, 그리고 봄봄', '몬스터 하우스', '무산일기', '미드소마', '바람과 함께 사라지다',
#        '벌새', '봉오동 전투', '분노의 질주: 홉스&쇼', '비트', '뽀로로 극장판 보물섬 대모험', '사랑의 선물',
#        '세상을 바꾼 변호인', '소공녀', '소중한 날의 꿈', '스탠 바이 미', '시인의 사랑',
#        '쏘아올린 불꽃, 밑에서 볼까? 옆에서 볼까?', '아이다호', '아이언 자이언트', '안녕 베일리',
#        '안녕, 티라노: 영원히, 함께', '알라딘', '애드 아스트라', '양자물리학', '어느 가족', '언더독',
#        '에곤 쉴레: 욕망이 그린 그림', '엑시트', '예스터데이', '우리들', '우리집',
#        '원스 어폰 어 타임... 인 할리우드', '유열의 음악앨범', '장고:분노의 추적자', '장기왕: 가락시장 레볼루션',
#        '장사리 : 잊혀진 영웅들', '저수지의 개들', '제미니 맨', '조커', '졸업', '주전장', '죽거나 혹은 나쁘거나',
# ...

# %%
target_col = ['교회오빠', '82년생 김지영', '조커', '기생충', '터미네이터: 다크 페이트']
plt.figure(figsize=(12,8))
plt.plot(movie_pivot[target_col])
plt.legend(target_col, loc='best')
plt.tick_params(bottom=False, labelbottom=False)
plt.show()

# %%
url = "https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cnt&date=20190319"
page2 = urlopen(url)

soup2 = BeautifulSoup(page2, "html.parser")
soup2
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cnt&amp;date=20190319" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
tmp = soup2.find('tbody')

# %%
tmps= []

tmps = tmp.find_all('a')

# %%
tmps[0]
# Out:
# <a href="/movie/bi/mi/basic.naver?code=132623" title="캡틴 마블">캡틴 마블</a>

# %%
tmps[1]
# Out:
# <a href="/movie/bi/mi/basic.naver?code=180425" title="이스케이프 룸">이스케이프 룸</a>

# %%
tmps[0].string
# Out:
# '캡틴 마블'

# %%
from urllib.request import Request, urlopen
from fake_useragent import UserAgent

from bs4 import BeautifulSoup

url = "http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/"

ua = UserAgent()
req = Request(url, headers={"user-agent": ua.chrome})
html = urlopen(req)
soup = BeautifulSoup(html, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js">
#    </script>
#    <title>
#     The 50 Best Sandwiches in Chicago – Chicago Magazine
#    </title>
#    <style type="text/css">
#     .heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateor_sss_svg,.heateor_sss_standard_follow_icons_container .heateor_sss_svg{
# ...

# %%
print(soup.find_all("div", "sammy"))
# Out:
# [<div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">2</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
# Au Cheval<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">3</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
# Xoco<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">4</div>
# ...

# %%
len(soup.find_all("div", "sammy"))
# Out:
# 50

# %%
print(soup.find_all("div", "sammy")[0])
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>

# %%
tmp_one = soup.find_all("div", "sammy")[0]
type(tmp_one)
# Out:
# bs4.element.Tag

# %%
tmp_one.find(class_="sammyRank").get_text()
# Out:
# '1'

# %%
tmp_one.find(class_="sammyListing").get_text()
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
tmp_one.find("a")["href"]
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
import re

tmp_string = tmp_one.find(class_="sammyListing").get_text()
re.split(("\n|\r\n"), tmp_string)
# Out:
# ['BLT', 'Old Oak Tap', 'Read more ']

# %%
print(re.split(("\n|\r\n"), tmp_string)[0])
print(re.split(("\n|\r\n"), tmp_string)[1])
# Out:
# BLT
# Old Oak Tap

# %%
url_base = "http://www.chicagomag.com"

print(url_base)
print(tmp_one.find('a')['href'])
# Out:
# http://www.chicagomag.com
# /Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/

# %%
from urllib.parse import urljoin
urljoin(url_base, tmp_one.find('a')['href'])
# Out:
# 'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
tmp_one = soup.find_all('div', 'sammy')[10].find('a')['href']
tmp_one
# Out:
# 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Lula-Cafe-Ham-and-Raclette-Panino/'

# %%
urljoin(url_base, tmp_one)
# Out:
# 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Lula-Cafe-Ham-and-Raclette-Panino/'

# %%
from urllib.parse import urljoin

url_base = "http://www.chicagomag.com"

rank = []
main_menu = []
cafe_name = []
url_add  = []

list_soup = soup.find_all("div", "sammy")

for item in list_soup:
    rank.append(item.find(class_="sammyRank").get_text())
    tmp_string = item.find(class_="sammyListing").get_text()
    main_menu.append(re.split(("\n|\r\n"), tmp_string)[0])
    cafe_name.append(re.split(("\n|\r\n"), tmp_string)[1])
    url_add.append(urljoin(url_base, item.find("a")["href"]))

# %%
rank[:5]
# Out:
# ['1', '2', '3', '4', '5']

# %%
main_menu[:5]
# Out:
# ['BLT', 'Fried Bologna', 'Woodland Mushroom', 'Roast Beef', 'PB&L']

# %%
cafe_name[:5]
# Out:
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']

# %%
url_add[:5]
# Out:
# ['http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/']

# %%
len(rank), len(main_menu), len(cafe_name), len(url_add)
# Out:
# (50, 50, 50, 50)

# %%
import pandas as pd

data = {"Rank": rank, "Menu":main_menu, "Cafe": cafe_name, "URL": url_add}
df = pd.DataFrame(data)
df.head()
# Out:
#   Rank               Menu                    Cafe  \
# 0    1                BLT             Old Oak Tap
# 1    2      Fried Bologna               Au Cheval
# 2    3  Woodland Mushroom                    Xoco
# 3    4         Roast Beef               Al’s Deli
# 4    5               PB&L  Publican Quality Meats
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df = pd.DataFrame(data, columns=["Rank", "Cafe", "Menu", "URL"])
df.head()
# Out:
#   Rank                    Cafe               Menu  \
# 0    1             Old Oak Tap                BLT
# 1    2               Au Cheval      Fried Bologna
# 2    3                    Xoco  Woodland Mushroom
# 3    4               Al’s Deli         Roast Beef
# 4    5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df.to_csv("../", sep=",", encoding = "utf-8")

# %%
import re

search_target = '''Luke Skywarker 02-123-4567 luke@daum.net
다스베이더 070-9999-9999 darth_vader@gmail.com 서울시 서초구 서초동 서초아파트
princess leia 010 2454 3457 leia@gmail.com'''

# %%
re.search('\d+', search_target).group()
# Out:
# '02'

# %%
re.search('[a-zA-Z]+', search_target).group()
# Out:
# 'Luke'

# %%
re.search('\d+-\d+-\d+', search_target).group()
# Out:
# '02-123-4567'

# %%
re.findall('\d+-\d+-\d+', search_target)
# Out:
# ['02-123-4567', '070-9999-9999']

# %%
re.findall('\w+@\w+[.]\w+', search_target)
# Out:
# ['luke@daum.net', 'darth_vader@gmail.com', 'leia@gmail.com']

# %%
re.findall('[가-힣]+', search_target)
# Out:
# ['다스베이더', '서울시', '서초구', '서초동', '서초아파트']

# %%
re.findall('[가-힣]+시\s[가-힣]+구\s[가-힣]+동', search_target)
# Out:
# ['서울시 서초구 서초동']

# %%
re.search('[가-힣]+아파트', search_target).span()
# Out:
# (95, 100)

# %%
search_target[95:100]
# Out:
# '서초아파트'

# %%
from tqdm import tqdm

# %%
df["URL"][0]
# Out:
# 'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
# html = urlopen(df['URL'][0])
req = Request(df["URL"][0], headers={"User-Agent": "Chrome"})
html = urlopen(req).read()

soup_tmp = BeautifulSoup(html, "html.parser")

# %%
print(soup_tmp.find("p","addy"))
# Out:
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
price_tmp = soup_tmp.find("p", "addy").get_text()
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
import re

re.split(".,", price_tmp)
# Out:
# ['\n$10. 2109 W. Chicago Ave', ' 773-772-040', ' theoldoaktap.com']

# %%
price_tmp = re.split(".,", price_tmp)[0]
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave'

# %%
re.search("\$\d+\.(\d+)?", price_tmp).group()
# Out:
# '$10.'

# %%
tmp = re.search("\$\d+\.(\d+)?", price_tmp).group()
price_tmp[len(tmp) + 2:]
# Out:
# '2109 W. Chicago Ave'

# %%
price = []
address = []

for n in df.index[:3]:
    req = Request(df["URL"][n], headers={"user-agent":ua.chrome})
    html = urlopen(req).read()

    soup_tmp = BeautifulSoup(html, "html.parser")

    gettings = soup_tmp.find("p", "addy").get_text()

    price_tmp = re.split(".,", gettings)[0]
    tmp = re.search("\$\d+\.(\d+)?", price_tmp).group()

    price.append(tmp)
    address.append(price_tmp[len(tmp) + 2 :])

print(price)
# Out:
# ['$10.', '$9.', '$9.50']

# %%
price = []
address = []

for idx, row in df[:50].iterrows():
    req = Request(row["URL"], headers={"user-agent":ua.chrome})
    html = urlopen(req).read()

    soup_tmp = BeautifulSoup(html, "html.parser")

    gettings = soup_tmp.find("p", "addy").get_text()

    price_tmp = re.split(".,", gettings)[0]
    tmp = re.search("\$\d+\.(\d+)?", price_tmp).group()

    price.append(tmp)
    address.append(price_tmp[len(tmp) + 2 :])

print(price)
# Out:
# ['$10.', '$9.', '$9.50', '$9.40', '$10.', '$7.25', '$16.', '$10.', '$9.', '$17.', '$11.', '$5.49', '$14.', '$10.', '$13.', '$4.50', '$11.95', '$11.50', '$6.25', '$15.', '$5.', '$6.', '$8.', '$5.99', '$7.52', '$11.95', '$7.50', '$12.95', '$7.', '$21.', '$9.79', '$9.75', '$13.', '$7.95', '$9.', '$9.', '$8.', '$8.', '$7.', '$6.', '$7.25', '$11.', '$6.', '$9.', '$5.49', '$8.', '$6.50', '$7.50', '$8.75', '$6.85']

# %%
price
# Out:
# ['$10.', '$9.', '$9.50']

# %%
address
# Out:
# ['2109 W. Chicago Ave', '800 W. Randolph St', ' 445 N. Clark St']

# %%
price = []
address = []

for idx, row in tqdm(df.iterrows()):
    req = Request(row["URL"], headers={"user-agent":ua.chrome})
    html = urlopen(req).read()

    soup_tmp = BeautifulSoup(html, "html.parser")

    gettings = soup_tmp.find("p", "addy").get_text()

    price_tmp = re.split(".,", gettings)[0]
    tmp = re.search("\$\d+\.(\d+)?", price_tmp).group()

    price.append(tmp)
    address.append(price_tmp[len(tmp) + 2 :])

print(price)
# Out:
# 50it [01:03,  1.27s/it]
# ['$10.', '$9.', '$9.50', '$9.40', '$10.', '$7.25', '$16.', '$10.', '$9.', '$17.', '$11.', '$5.49', '$14.', '$10.', '$13.', '$4.50', '$11.95', '$11.50', '$6.25', '$15.', '$5.', '$6.', '$8.', '$5.99', '$7.52', '$11.95', '$7.50', '$12.95', '$7.', '$21.', '$9.79', '$9.75', '$13.', '$7.95', '$9.', '$9.', '$8.', '$8.', '$7.', '$6.', '$7.25', '$11.', '$6.', '$9.', '$5.49', '$8.', '$6.50', '$7.50', '$8.75', '$6.85']

# %%
len(price), len(address), len(df)
# Out:
# (50, 50, 50)

# %%
df["Price"] = price
df["Address"] = address

df = df.loc[:, ["Rank", "Cafe", "Menu", "Price", "Address"]]
df.set_index("Rank", inplace=True)
df.head()
# Out:
#                         Cafe               Menu  Price              Address
# Rank
# 1                Old Oak Tap                BLT   $10.  2109 W. Chicago Ave
# 2                  Au Cheval      Fried Bologna    $9.   800 W. Randolph St
# 3                       Xoco  Woodland Mushroom  $9.50      445 N. Clark St
# 4                  Al’s Deli         Roast Beef  $9.40         914 Noyes St
# 5     Publican Quality Meats               PB&L   $10.    825 W. Fulton Mkt

# %%
df.to_csv(
    "../data/chicago_sandwich2.csv", sep=",", encoding="UTF-8"
)

# %%
import googlemaps

gmaps_key = "AIzaSyDFgI36AGZjHkjTI5V2ajY-rhE25n94M2k"
gmaps = googlemaps.Client(key=gmaps_key)

geocode = gmaps.geocode("1547 N. Wells St Chicago")
print(geocode[0].get("geometry")["location"]["lat"])
print(geocode[0].get("geometry")["location"]["lng"])
# Out:
# 41.9105258
# -87.6343775

# %%
import folium
import pandas as pd
import numpy as np
import googlemaps
from tqdm import tqdm

df = pd.read_csv("../data/chicago_sandwich2.csv", index_col=0)
df.tail(10)
# Out:
#                              Cafe                                    Menu  \
# Rank
# 41                 Z&H MarketCafe                              The Marty
# 42     Market House on the Square                               Whitefish
# 43           Elaine’s Coffee Call  Oat Bread, Pecan Butter, and Fruit Jam
# 44    Marion Street Cheese Market                        Cauliflower Melt
# 45                       Cafecito                                  Cubana
# 46                       Chickpea                                   Kufta
# 47         The Goddess and Grocer                      Debbie’s Egg Salad
# 48                        Zenwich                              Beef Curry
# 49                Toni Patisserie                           Le Végétarien
# 50                Phoebe’s Bakery                              The Gatsby
#
#       Price               Address
# Rank
# 41    $7.25       1323 E. 57th St
# 42     $11.        655 Forest Ave
# 43      $6.          Hotel Lincol
# ...

# %%
gmaps_key = "AIzaSyDFgI36AGZjHkjTI5V2ajY-rhE25n94M2k"
gmaps = googlemaps.Client(key=gmaps_key)

lat = []
lng = []

for idx, row in tqdm(df.iterrows()):
    if not row["Address"] == "Multiple location":
        full_address = row["Address"] + ", " + "Chicago"
        geocode = gmaps.geocode(full_address)
        lat.append(geocode[0].get("geometry")["location"]["lat"])
        lng.append(geocode[0].get("geometry")["location"]["lng"])
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# 50it [00:04, 10.97it/s]

# %%
len(lat), len(lng)
# Out:
# (50, 50)

# %%
df["lat"] = lat
df["lng"] = lng
df.head()
# Out:
#                         Cafe               Menu  Price              Address  \
# Rank
# 1                Old Oak Tap                BLT   $10.  2109 W. Chicago Ave
# 2                  Au Cheval      Fried Bologna    $9.   800 W. Randolph St
# 3                       Xoco  Woodland Mushroom  $9.50      445 N. Clark St
# 4                  Al’s Deli         Roast Beef  $9.40         914 Noyes St
# 5     Publican Quality Meats               PB&L   $10.    825 W. Fulton Mkt
#
#             lat        lng
# Rank
# 1     41.895558 -87.679967
# 2     41.884639 -87.647590
# 3     41.890523 -87.630783
# 4     41.878114 -87.629798
# 5     41.886604 -87.648536

# %%
mapping = folium.Map(location=[41.8781136,-87.6297982], zoom_start=11)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
mapping = folium.Map(location=[41.8781136,-87.6297982], zoom_start=11)

for idx, row in df.iterrows():
    if not row["Address"] == "Multiple location":
        folium.Marker([row["lat"], row["lng"]], popup=row["Cafe"]).add_to(
            mapping
        )

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
